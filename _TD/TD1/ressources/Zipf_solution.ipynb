# %% [markdown]
# <a href="https://colab.research.google.com/github/ljpetkovic/M2SOL034/blob/main/_TD/TD1/ressources/Zipf_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Implémentation pour visualiser la loi de Zipf en Python.
#
# Code adapté de [Rherrad (_s.d._)](https://www.iana-data.org/fondamentaux/846-loi-de-zipf-et-text-mining.html).

# %%
import matplotlib.pyplot as plt
from collections import Counter
import re

file_path = 'zipf.txt' # importer le fichier directement dans Colab (barre à gauche)

with open(file_path, 'r') as file:
    file_content = file.read()

# print(file_content)

# Prétraitement du texte
mots = re.findall(r'\b\w+\b', texte.lower())

# Compter la fréquence des mots
freq_mots = Counter(mots)

# Trier les mots par fréquence
mots_tries = freq_mots.most_common()

# Extraire les fréquences et les rangs
rangs = range(1, len(mots_tries) + 1)
frequences = [freq for mot, freq in mots_tries]


# Tracer la loi de Zipf
plt.figure(figsize=(10, 6))
plt.loglog(rangs, frequences, marker=".")
plt.title("Loi de Zipf pour le texte donné")
plt.xlabel("Rang des mots")
plt.ylabel("Fréquence des mots")
plt.grid(True, which="both")
plt.show()
